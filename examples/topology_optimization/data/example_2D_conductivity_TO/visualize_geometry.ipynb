# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
name = 'Green_Jacobi_eta_0.0625_w_5.0_final.npy'
name = 'Green_Jacobi_eta_0.0625_w_5_final.npy'
geometry = np.load(name)

print()

# %%
plt.figure()
plt.pcolormesh(geometry.T, cmap=mpl.cm.Greys)# transpose becouse of the order x,y
plt.clim(0, 1)
plt.colorbar()
plt.show()
